# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 649

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vohipaho
# City not found. Skipping...
# Processing Record 2 of Set 1 | mawu
# Processing Record 3 of Set 1 | ribeira grande
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | christchurch
# Processing Record 6 of Set 1 | poiares
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | whitehorse
# Processing Record 9 of Set 1 | stanley
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | mana
# Processing Record 12 of Set 1 | adamstown
# Processing Record 13 of Set 1 | holyhead
# Processing Record 14 of Set 1 | olonkinbyen
# Processing Record 15 of Set 1 | piacabucu
# Processing Record 16 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 17 of Set 1 | kavaratti
# Processing Record 18 of Set 1 | chibougamau
# Processing Record 19 of Set 1 | el galpon
# Processing Record 20 of Set 1 | mili
# Processing Record 21 of Set 1 | tiksi
# Processing Record 22 of Set 1 | edinburgh of the seven seas
# Processing Record 23 of Set 1 | goure
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | fort bragg
# Processing Record 26 of Set 1 | torre-pacheco
# Processing Record 27 of Set 1 | mhamid
# Processing Record 28 of Set 1 | qalat
# Processing Record 29 of Set 1 | kill devil hills
# Processing Record 30 of Set 1 | tadine
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | sirte
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | mount isa
# Processing Record 35 of Set 1 | glace bay
# Processing Record 36 of Set 1 | talnakh
# Processing Record 37 of Set 1 | ravar
# Processing Record 38 of Set 1 | quellon
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | swakopmund
# Processing Record 41 of Set 1 | fale old settlement
# Processing Record 42 of Set 1 | waitangi
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | puerto gaitan
# Processing Record 45 of Set 1 | koster
# Processing Record 46 of Set 1 | namibe
# Processing Record 47 of Set 1 | palikir - national government center
# Processing Record 48 of Set 1 | gunjur
# Processing Record 49 of Set 1 | aykhal
# Processing Record 50 of Set 1 | suntar
# Processing Record 0 of Set 2 | kingston
# Processing Record 1 of Set 2 | aberystwyth
# Processing Record 2 of Set 2 | blackmans bay
# Processing Record 3 of Set 2 | bethel
# Processing Record 4 of Set 2 | cabo san lucas
# Processing Record 5 of Set 2 | nemuro
# Processing Record 6 of Set 2 | robore
# Processing Record 7 of Set 2 | west island
# Processing Record 8 of Set 2 | kaspiyskiy
# Processing Record 9 of Set 2 | ta`u
# Processing Record 10 of Set 2 | port pirie
# Processing Record 11 of Set 2 | ushuaia
# Processing Record 12 of Set 2 | port mathurin
# Processing Record 13 of Set 2 | shingu
# Processing Record 14 of Set 2 | yanam
# Processing Record 15 of Set 2 | san luis de la loma
# Processing Record 16 of Set 2 | wailua homesteads
# Processing Record 17 of Set 2 | rio preto da eva
# Processing Record 18 of Set 2 | uturoa
# Processing Record 19 of Set 2 | tura
# Processing Record 20 of Set 2 | bushland beach
# City not found. Skipping...
# Processing Record 21 of Set 2 | necochea
# Processing Record 22 of Set 2 | nemyriv
# Processing Record 23 of Set 2 | dakhla
# Processing Record 24 of Set 2 | bikenibeu village
# Processing Record 25 of Set 2 | egilsstadir
# Processing Record 26 of Set 2 | ghat
# Processing Record 27 of Set 2 | castilho
# Processing Record 28 of Set 2 | newtown
# Processing Record 29 of Set 2 | mwinilunga
# Processing Record 30 of Set 2 | floro
# Processing Record 31 of Set 2 | haiku-pauwela
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | happy valley-goose bay
# Processing Record 34 of Set 2 | ajdabiya
# Processing Record 35 of Set 2 | qaqortoq
# Processing Record 36 of Set 2 | udachny
# Processing Record 37 of Set 2 | alice springs
# Processing Record 38 of Set 2 | zhosaly
# Processing Record 39 of Set 2 | kailua-kona
# Processing Record 40 of Set 2 | papao
# Processing Record 41 of Set 2 | hamilton
# Processing Record 42 of Set 2 | longyearbyen
# Processing Record 43 of Set 2 | jimenez
# Processing Record 44 of Set 2 | veraval
# Processing Record 45 of Set 2 | puerto natales
# Processing Record 46 of Set 2 | badger
# Processing Record 47 of Set 2 | forster
# Processing Record 48 of Set 2 | alaghsas
# Processing Record 49 of Set 2 | badarwas
# Processing Record 0 of Set 3 | new plymouth
# Processing Record 1 of Set 3 | kaka
# Processing Record 2 of Set 3 | razampeta
# Processing Record 3 of Set 3 | soio
# Processing Record 4 of Set 3 | argo
# Processing Record 5 of Set 3 | papatowai
# Processing Record 6 of Set 3 | yeppoon
# Processing Record 7 of Set 3 | belmonte
# Processing Record 8 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 9 of Set 3 | kasongo-lunda
# Processing Record 10 of Set 3 | isafjordur
# Processing Record 11 of Set 3 | sabt alalayah
# City not found. Skipping...
# Processing Record 12 of Set 3 | klyuchi
# Processing Record 13 of Set 3 | palmer
# Processing Record 14 of Set 3 | rochester
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | mount pearl
# Processing Record 17 of Set 3 | lata
# Processing Record 18 of Set 3 | kismayo
# Processing Record 19 of Set 3 | hawaiian paradise park
# Processing Record 20 of Set 3 | ciudad gustavo diaz ordaz
# Processing Record 21 of Set 3 | invercargill
# Processing Record 22 of Set 3 | bilibino
# Processing Record 23 of Set 3 | vorgashor
# Processing Record 24 of Set 3 | arrah
# Processing Record 25 of Set 3 | badagry
# Processing Record 26 of Set 3 | uryupinsk
# Processing Record 27 of Set 3 | al bawiti
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | cafayate
# Processing Record 30 of Set 3 | tolanaro
# Processing Record 31 of Set 3 | mul
# Processing Record 32 of Set 3 | inyonga
# Processing Record 33 of Set 3 | ust-nera
# Processing Record 34 of Set 3 | juneau
# Processing Record 35 of Set 3 | alofi
# Processing Record 36 of Set 3 | hobyo
# Processing Record 37 of Set 3 | walvis bay
# Processing Record 38 of Set 3 | atafu village
# Processing Record 39 of Set 3 | saint joseph
# Processing Record 40 of Set 3 | holualoa
# Processing Record 41 of Set 3 | port saint john's
# Processing Record 42 of Set 3 | tralee
# Processing Record 43 of Set 3 | bhimunipatnam
# Processing Record 44 of Set 3 | isangel
# Processing Record 45 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 46 of Set 3 | broome
# Processing Record 47 of Set 3 | labasa
# Processing Record 48 of Set 3 | dudinka
# Processing Record 49 of Set 3 | harstad
# Processing Record 0 of Set 4 | a estrada
# Processing Record 1 of Set 4 | siwa oasis
# Processing Record 2 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 3 of Set 4 | victorica
# Processing Record 4 of Set 4 | al ghayzah
# Processing Record 5 of Set 4 | mayya
# Processing Record 6 of Set 4 | liaoyuan
# Processing Record 7 of Set 4 | sisimiut
# Processing Record 8 of Set 4 | punta arenas
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | tarawa
# Processing Record 11 of Set 4 | novomykolayivka
# Processing Record 12 of Set 4 | axim
# Processing Record 13 of Set 4 | puerto aysen
# Processing Record 14 of Set 4 | rotonda west
# Processing Record 15 of Set 4 | villa emilio carranza
# Processing Record 16 of Set 4 | harper
# Processing Record 17 of Set 4 | andorra
# Processing Record 18 of Set 4 | mumford
# Processing Record 19 of Set 4 | olyokminsk
# Processing Record 20 of Set 4 | norilsk
# Processing Record 21 of Set 4 | aykol
# City not found. Skipping...
# Processing Record 22 of Set 4 | maryborough
# Processing Record 23 of Set 4 | zhukovo
# Processing Record 24 of Set 4 | kapuskasing
# Processing Record 25 of Set 4 | noumea
# Processing Record 26 of Set 4 | picos
# Processing Record 27 of Set 4 | tofol
# Processing Record 28 of Set 4 | fort mcmurray
# Processing Record 29 of Set 4 | tamanrasset
# Processing Record 30 of Set 4 | gustavsberg
# Processing Record 31 of Set 4 | jam sahib
# Processing Record 32 of Set 4 | kasongo
# Processing Record 33 of Set 4 | port douglas
# Processing Record 34 of Set 4 | stawell
# Processing Record 35 of Set 4 | sambava
# Processing Record 36 of Set 4 | gwadar
# Processing Record 37 of Set 4 | st. john's
# Processing Record 38 of Set 4 | new norfolk
# Processing Record 39 of Set 4 | mont-dore
# Processing Record 40 of Set 4 | dwarka
# Processing Record 41 of Set 4 | sao joao da barra
# Processing Record 42 of Set 4 | upata
# Processing Record 43 of Set 4 | yulinshi
# Processing Record 44 of Set 4 | mount gambier
# Processing Record 45 of Set 4 | machico
# Processing Record 46 of Set 4 | wetaskiwin
# Processing Record 47 of Set 4 | veshenskaya
# Processing Record 48 of Set 4 | karratha
# Processing Record 49 of Set 4 | iqaluit
# Processing Record 0 of Set 5 | aki
# Processing Record 1 of Set 5 | mawlaik
# Processing Record 2 of Set 5 | college
# Processing Record 3 of Set 5 | carnarvon
# Processing Record 4 of Set 5 | susuman
# Processing Record 5 of Set 5 | versailles
# Processing Record 6 of Set 5 | daru
# Processing Record 7 of Set 5 | kodiak
# Processing Record 8 of Set 5 | lihue
# Processing Record 9 of Set 5 | jamestown
# Processing Record 10 of Set 5 | ingeniero jacobacci
# Processing Record 11 of Set 5 | enewetak
# Processing Record 12 of Set 5 | san antonio de pale
# Processing Record 13 of Set 5 | houlton
# Processing Record 14 of Set 5 | jurmala
# Processing Record 15 of Set 5 | port alfred
# Processing Record 16 of Set 5 | buraydah
# Processing Record 17 of Set 5 | benghazi
# Processing Record 18 of Set 5 | jabor
# Processing Record 19 of Set 5 | constantia
# Processing Record 20 of Set 5 | zangguy
# City not found. Skipping...
# Processing Record 21 of Set 5 | pimentel
# Processing Record 22 of Set 5 | ancud
# Processing Record 23 of Set 5 | ilabaya
# Processing Record 24 of Set 5 | margaret river
# Processing Record 25 of Set 5 | taroa
# Processing Record 26 of Set 5 | newman
# Processing Record 27 of Set 5 | santo andre
# Processing Record 28 of Set 5 | belyy yar
# Processing Record 29 of Set 5 | lospalos
# Processing Record 30 of Set 5 | chinhoyi
# Processing Record 31 of Set 5 | tucuma
# Processing Record 32 of Set 5 | la passe
# Processing Record 33 of Set 5 | pibor
# City not found. Skipping...
# Processing Record 34 of Set 5 | pontes e lacerda
# Processing Record 35 of Set 5 | beteza
# City not found. Skipping...
# Processing Record 36 of Set 5 | mugia
# Processing Record 37 of Set 5 | zaozersk
# Processing Record 38 of Set 5 | abqaiq
# Processing Record 39 of Set 5 | novopskov
# Processing Record 40 of Set 5 | tromso
# Processing Record 41 of Set 5 | port elizabeth
# Processing Record 42 of Set 5 | dzuunharaa
# Processing Record 43 of Set 5 | whangarei
# Processing Record 44 of Set 5 | vila franca do campo
# Processing Record 45 of Set 5 | dolores
# Processing Record 46 of Set 5 | hithadhoo
# Processing Record 47 of Set 5 | richards bay
# Processing Record 48 of Set 5 | igarka
# Processing Record 49 of Set 5 | kenai
# Processing Record 0 of Set 6 | kitimat
# Processing Record 1 of Set 6 | howrah
# Processing Record 2 of Set 6 | boguchany
# Processing Record 3 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 6 | laguna
# Processing Record 5 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 6 of Set 6 | am timan
# Processing Record 7 of Set 6 | berezovyy
# Processing Record 8 of Set 6 | manaure
# Processing Record 9 of Set 6 | aripuana
# Processing Record 10 of Set 6 | novodvinsk
# Processing Record 11 of Set 6 | yakymivka
# Processing Record 12 of Set 6 | issoudun
# Processing Record 13 of Set 6 | nyurba
# Processing Record 14 of Set 6 | bamboo flat
# Processing Record 15 of Set 6 | kraaifontein
# Processing Record 16 of Set 6 | pisco
# Processing Record 17 of Set 6 | awjilah
# Processing Record 18 of Set 6 | flying fish cove
# Processing Record 19 of Set 6 | valparaiso
# Processing Record 20 of Set 6 | vilyuysk
# Processing Record 21 of Set 6 | saipan
# Processing Record 22 of Set 6 | chonchi
# Processing Record 23 of Set 6 | saint-joseph
# Processing Record 24 of Set 6 | barcelos
# Processing Record 25 of Set 6 | isle of lewis
# City not found. Skipping...
# Processing Record 26 of Set 6 | weyburn
# Processing Record 27 of Set 6 | torghay
# Processing Record 28 of Set 6 | thunder bay
# Processing Record 29 of Set 6 | thanh hoa
# Processing Record 30 of Set 6 | okha
# Processing Record 31 of Set 6 | vega de alatorre
# Processing Record 32 of Set 6 | vacha
# Processing Record 33 of Set 6 | burang
# Processing Record 34 of Set 6 | antonio enes
# Processing Record 35 of Set 6 | karyes
# Processing Record 36 of Set 6 | yuzhno-kurilsk
# Processing Record 37 of Set 6 | aban
# Processing Record 38 of Set 6 | gobabis
# Processing Record 39 of Set 6 | viedma
# Processing Record 40 of Set 6 | qapqal
# City not found. Skipping...
# Processing Record 41 of Set 6 | qarazhal
# Processing Record 42 of Set 6 | san patricio
# Processing Record 43 of Set 6 | kudahuvadhoo
# Processing Record 44 of Set 6 | zapolyarnyy
# Processing Record 45 of Set 6 | san pedro pochutla
# Processing Record 46 of Set 6 | miri
# Processing Record 47 of Set 6 | smiths falls
# Processing Record 48 of Set 6 | almeirim
# Processing Record 49 of Set 6 | sretensk
# Processing Record 0 of Set 7 | devinuwara
# City not found. Skipping...
# Processing Record 1 of Set 7 | tomohon
# Processing Record 2 of Set 7 | purificacion
# Processing Record 3 of Set 7 | iranshahr
# Processing Record 4 of Set 7 | yevpatoriya
# Processing Record 5 of Set 7 | port lincoln
# Processing Record 6 of Set 7 | ensenada
# Processing Record 7 of Set 7 | kisangani
# Processing Record 8 of Set 7 | bubaque
# Processing Record 9 of Set 7 | san rafael del yuma
# Processing Record 10 of Set 7 | pangody
# Processing Record 11 of Set 7 | salekhard
# Processing Record 12 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 13 of Set 7 | jianshui
# Processing Record 14 of Set 7 | aldinga beach
# Processing Record 15 of Set 7 | tazovsky
# Processing Record 16 of Set 7 | punta alta
# Processing Record 17 of Set 7 | ilulissat
# Processing Record 18 of Set 7 | robbah
# Processing Record 19 of Set 7 | silkeborg
# Processing Record 20 of Set 7 | ad dawadimi
# Processing Record 21 of Set 7 | touros
# Processing Record 22 of Set 7 | sombrerete
# Processing Record 23 of Set 7 | itaituba
# Processing Record 24 of Set 7 | tokar
# Processing Record 25 of Set 7 | amga
# Processing Record 26 of Set 7 | brzeg
# Processing Record 27 of Set 7 | saint croix
# Processing Record 28 of Set 7 | port hedland
# Processing Record 29 of Set 7 | pariaman
# Processing Record 30 of Set 7 | lorengau
# Processing Record 31 of Set 7 | varberg
# Processing Record 32 of Set 7 | ambon
# Processing Record 33 of Set 7 | tual
# Processing Record 34 of Set 7 | geraldton
# Processing Record 35 of Set 7 | saint-philippe
# Processing Record 36 of Set 7 | raja
# Processing Record 37 of Set 7 | kegen
# Processing Record 38 of Set 7 | sao felix do xingu
# Processing Record 39 of Set 7 | tindouf
# Processing Record 40 of Set 7 | aral
# Processing Record 41 of Set 7 | susanville
# Processing Record 42 of Set 7 | puerto ayora
# Processing Record 43 of Set 7 | hirara
# Processing Record 44 of Set 7 | kolonia
# Processing Record 45 of Set 7 | alesund
# Processing Record 46 of Set 7 | zhatay
# Processing Record 47 of Set 7 | zarghun shahr
# Processing Record 48 of Set 7 | aktau
# Processing Record 49 of Set 7 | kuala tungkal
# Processing Record 0 of Set 8 | kerikeri
# Processing Record 1 of Set 8 | bridgwater
# Processing Record 2 of Set 8 | roshchino
# Processing Record 3 of Set 8 | kemijarvi
# Processing Record 4 of Set 8 | choibalsan
# Processing Record 5 of Set 8 | guerrero negro
# Processing Record 6 of Set 8 | thurgoona
# Processing Record 7 of Set 8 | borogontsy
# Processing Record 8 of Set 8 | rongelap
# Processing Record 9 of Set 8 | birao
# Processing Record 10 of Set 8 | inirida
# Processing Record 11 of Set 8 | hemsby
# Processing Record 12 of Set 8 | jala
# Processing Record 13 of Set 8 | buala
# Processing Record 14 of Set 8 | ostersund
# Processing Record 15 of Set 8 | pemba
# Processing Record 16 of Set 8 | filadelfia
# Processing Record 17 of Set 8 | hilo
# Processing Record 18 of Set 8 | mejit
# Processing Record 19 of Set 8 | keflavik
# Processing Record 20 of Set 8 | bandar-e lengeh
# Processing Record 21 of Set 8 | hayma'
# City not found. Skipping...
# Processing Record 22 of Set 8 | arraial do cabo
# Processing Record 23 of Set 8 | santarem
# Processing Record 24 of Set 8 | pionerskiy
# Processing Record 25 of Set 8 | pindobacu
# Processing Record 26 of Set 8 | piscu vechi
# Processing Record 27 of Set 8 | tarko-sale
# Processing Record 28 of Set 8 | usinsk
# Processing Record 29 of Set 8 | ola
# Processing Record 30 of Set 8 | yarmouth
# Processing Record 31 of Set 8 | xinguara
# City not found. Skipping...
# Processing Record 32 of Set 8 | kiunga
# Processing Record 33 of Set 8 | nova vicosa
# Processing Record 34 of Set 8 | nova floresta
# Processing Record 35 of Set 8 | guna
# Processing Record 36 of Set 8 | bairnsdale
# Processing Record 37 of Set 8 | santiago
# Processing Record 38 of Set 8 | prince george
# Processing Record 39 of Set 8 | conde
# Processing Record 40 of Set 8 | jabat
# Processing Record 41 of Set 8 | mbarara
# Processing Record 42 of Set 8 | lerwick
# Processing Record 43 of Set 8 | anapa
# Processing Record 44 of Set 8 | aksu
# Processing Record 45 of Set 8 | yanchep
# Processing Record 46 of Set 8 | luderitz
# Processing Record 47 of Set 8 | yilan
# Processing Record 48 of Set 8 | kalix
# Processing Record 49 of Set 8 | lazaro cardenas
# Processing Record 0 of Set 9 | fortuna
# Processing Record 1 of Set 9 | bardai
# Processing Record 2 of Set 9 | dursunbey
# Processing Record 3 of Set 9 | brisas de zicatela
# Processing Record 4 of Set 9 | conduaga
# Processing Record 5 of Set 9 | fabens
# Processing Record 6 of Set 9 | mabaruma
# Processing Record 7 of Set 9 | carbonear
# Processing Record 8 of Set 9 | petropavlovka
# Processing Record 9 of Set 9 | smithers
# Processing Record 10 of Set 9 | nuku'alofa
# Processing Record 11 of Set 9 | mogocha
# Processing Record 12 of Set 9 | belozersk
# Processing Record 13 of Set 9 | altai
# Processing Record 14 of Set 9 | isyangulovo
# Processing Record 15 of Set 9 | aswan
# Processing Record 16 of Set 9 | tyukhtet
# Processing Record 17 of Set 9 | longgang
# Processing Record 18 of Set 9 | nar'yan-mar
# Processing Record 19 of Set 9 | vorkuta
# Processing Record 20 of Set 9 | ghadamis
# Processing Record 21 of Set 9 | guilmaro
# City not found. Skipping...
# Processing Record 22 of Set 9 | ulladulla
# Processing Record 23 of Set 9 | tazacorte
# Processing Record 24 of Set 9 | hanawa
# Processing Record 25 of Set 9 | kruisfontein
# Processing Record 26 of Set 9 | antofagasta
# Processing Record 27 of Set 9 | north bend
# Processing Record 28 of Set 9 | afaahiti
# Processing Record 29 of Set 9 | nagqu
# Processing Record 30 of Set 9 | miquelon
# Processing Record 31 of Set 9 | minas de marcona
# Processing Record 32 of Set 9 | vilyuchinsk
# Processing Record 33 of Set 9 | afif
# Processing Record 34 of Set 9 | zhob
# Processing Record 35 of Set 9 | fort abbas
# Processing Record 36 of Set 9 | kolonia town
# Processing Record 37 of Set 9 | kargasok
# Processing Record 38 of Set 9 | anadyr
# Processing Record 39 of Set 9 | muisne
# Processing Record 40 of Set 9 | sinop
# Processing Record 41 of Set 9 | at taj
# Processing Record 42 of Set 9 | pathardi
# Processing Record 43 of Set 9 | aldan
# Processing Record 44 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 45 of Set 9 | alzamay
# Processing Record 46 of Set 9 | narvik
# Processing Record 47 of Set 9 | el granada
# Processing Record 48 of Set 9 | asia
# Processing Record 49 of Set 9 | sitka
# Processing Record 0 of Set 10 | oamaru
# Processing Record 1 of Set 10 | revda
# Processing Record 2 of Set 10 | utrik
# Processing Record 3 of Set 10 | sijunjung
# Processing Record 4 of Set 10 | prachuap khiri khan
# Processing Record 5 of Set 10 | selfoss
# Processing Record 6 of Set 10 | gamba
# Processing Record 7 of Set 10 | kapa'a
# Processing Record 8 of Set 10 | hafnarfjordur
# Processing Record 9 of Set 10 | aquidauana
# Processing Record 10 of Set 10 | puerto lempira
# Processing Record 11 of Set 10 | yakeshi
# Processing Record 12 of Set 10 | zheleznogorsk
# Processing Record 13 of Set 10 | hotan
# Processing Record 14 of Set 10 | boa vista
# Processing Record 15 of Set 10 | pesqueira
# Processing Record 16 of Set 10 | sao vicente
# Processing Record 17 of Set 10 | bayan nur
# City not found. Skipping...
# Processing Record 18 of Set 10 | zouerate
# Processing Record 19 of Set 10 | siracusa
# Processing Record 20 of Set 10 | korla
# Processing Record 21 of Set 10 | polyarnyy
# Processing Record 22 of Set 10 | tubarjal
# Processing Record 23 of Set 10 | hadibu
# Processing Record 24 of Set 10 | kuraymah
# Processing Record 25 of Set 10 | yangchun
# Processing Record 26 of Set 10 | celendin
# Processing Record 27 of Set 10 | bealanana
# Processing Record 28 of Set 10 | campechuela
# Processing Record 29 of Set 10 | tumsar
# Processing Record 30 of Set 10 | quincy
# Processing Record 31 of Set 10 | prince rupert
# Processing Record 32 of Set 10 | palatka
# Processing Record 33 of Set 10 | n'zeto
# Processing Record 34 of Set 10 | san fernando
# Processing Record 35 of Set 10 | galesong
# Processing Record 36 of Set 10 | vernon
# Processing Record 37 of Set 10 | praia da vitoria
# Processing Record 38 of Set 10 | dunedin
# Processing Record 39 of Set 10 | plastun
# Processing Record 40 of Set 10 | portland
# Processing Record 41 of Set 10 | ostrov
# Processing Record 42 of Set 10 | nieuw amsterdam
# Processing Record 43 of Set 10 | salalah
# Processing Record 44 of Set 10 | qom
# Processing Record 45 of Set 10 | mukhorshibir'
# City not found. Skipping...
# Processing Record 46 of Set 10 | salinopolis
# Processing Record 47 of Set 10 | altay
# Processing Record 48 of Set 10 | kilifi
# Processing Record 49 of Set 10 | elimaki
# Processing Record 0 of Set 11 | port shepstone
# Processing Record 1 of Set 11 | gizo
# Processing Record 2 of Set 11 | mont-laurier
# Processing Record 3 of Set 11 | arroyo
# Processing Record 4 of Set 11 | barranca
# Processing Record 5 of Set 11 | woolgoolga
# Processing Record 6 of Set 11 | morrope
# Processing Record 7 of Set 11 | caleta olivia
# Processing Record 8 of Set 11 | ivdel'
# Processing Record 9 of Set 11 | hancheng
# Processing Record 10 of Set 11 | muzayri'
# City not found. Skipping...
# Processing Record 11 of Set 11 | ust-tsilma
# Processing Record 12 of Set 11 | akjoujt
# Processing Record 13 of Set 11 | nurota
# Processing Record 14 of Set 11 | santa vitoria
# Processing Record 15 of Set 11 | sogod
# Processing Record 16 of Set 11 | trairi
# Processing Record 17 of Set 11 | azhikkal
# Processing Record 18 of Set 11 | tosontsengel
# Processing Record 19 of Set 11 | kostomuksha
# Processing Record 20 of Set 11 | tobruk
# Processing Record 21 of Set 11 | karoi
# Processing Record 22 of Set 11 | yangambi
# Processing Record 23 of Set 11 | pandan
# Processing Record 24 of Set 11 | arteche
# Processing Record 25 of Set 11 | chaihe
# Processing Record 26 of Set 11 | penha
# Processing Record 27 of Set 11 | horta
# Processing Record 28 of Set 11 | cueibet
# City not found. Skipping...
# Processing Record 29 of Set 11 | isola di capo rizzuto
# Processing Record 30 of Set 11 | lingcheng
# Processing Record 31 of Set 11 | bani walid
# Processing Record 32 of Set 11 | northam
# Processing Record 33 of Set 11 | port augusta
# Processing Record 34 of Set 11 | gebeit
# Processing Record 35 of Set 11 | brigantine
# Processing Record 36 of Set 11 | quelimane
# Processing Record 37 of Set 11 | el bayadh
# Processing Record 38 of Set 11 | zschorlau
# Processing Record 39 of Set 11 | kristiansund
# Processing Record 40 of Set 11 | sanctuary point
# Processing Record 41 of Set 11 | odacho-oda
# Processing Record 42 of Set 11 | san angelo
# Processing Record 43 of Set 11 | mahina
# Processing Record 44 of Set 11 | road town
# Processing Record 45 of Set 11 | saldanha
# Processing Record 46 of Set 11 | weno
# Processing Record 47 of Set 11 | buka
# Processing Record 48 of Set 11 | mega
# Processing Record 49 of Set 11 | ribeira brava
# Processing Record 0 of Set 12 | agat village
# Processing Record 1 of Set 12 | queenstown
# Processing Record 2 of Set 12 | konakovo
# Processing Record 3 of Set 12 | nova sintra
# Processing Record 4 of Set 12 | grand falls-windsor
# Processing Record 5 of Set 12 | isla mujeres
# Processing Record 6 of Set 12 | colonia
# Processing Record 7 of Set 12 | oriximina
# Processing Record 8 of Set 12 | tarrafal de sao nicolau
# Processing Record 9 of Set 12 | iskateley
# Processing Record 10 of Set 12 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 11 of Set 12 | nantucket
# Processing Record 12 of Set 12 | faya-largeau
# Processing Record 13 of Set 12 | bonthe
# Processing Record 14 of Set 12 | dire
# Processing Record 15 of Set 12 | oranjemund
# Processing Record 16 of Set 12 | masaya sur
# Processing Record 17 of Set 12 | el gouna
# Processing Record 18 of Set 12 | howard springs
# Processing Record 19 of Set 12 | kalmunai
# Processing Record 20 of Set 12 | nadi
# Processing Record 21 of Set 12 | tarfaya
# Processing Record 22 of Set 12 | 'ibri
# City not found. Skipping...
# Processing Record 23 of Set 12 | rikaze
# Processing Record 24 of Set 12 | nogliki
# Processing Record 25 of Set 12 | weligama
# Processing Record 26 of Set 12 | crane
# Processing Record 27 of Set 12 | la ronge
# Processing Record 28 of Set 12 | codajas
# Processing Record 29 of Set 12 | marathon
# Processing Record 30 of Set 12 | maceio
# Processing Record 31 of Set 12 | murzuq
# Processing Record 32 of Set 12 | zabol
# Processing Record 33 of Set 12 | fort st. john
# Processing Record 34 of Set 12 | bafata
# Processing Record 35 of Set 12 | otjiwarongo
# Processing Record 36 of Set 12 | cooper's town
# Processing Record 37 of Set 12 | aitape
# Processing Record 38 of Set 12 | tinogasta
# Processing Record 39 of Set 12 | anna regina
# Processing Record 40 of Set 12 | meadow lake
# Processing Record 41 of Set 12 | sitangkai
# Processing Record 42 of Set 12 | elmendorf air force base
# City not found. Skipping...
# Processing Record 43 of Set 12 | dryden
# Processing Record 44 of Set 12 | tsaratanana
# Processing Record 45 of Set 12 | island harbour
# Processing Record 46 of Set 12 | neryungri
# Processing Record 47 of Set 12 | pemangkat
# Processing Record 48 of Set 12 | taksimo
# Processing Record 49 of Set 12 | celestun
# Processing Record 0 of Set 13 | gornopravdinsk
# Processing Record 1 of Set 13 | saksaul'skiy
# City not found. Skipping...
# Processing Record 2 of Set 13 | peace river
# Processing Record 3 of Set 13 | yuanping
# Processing Record 4 of Set 13 | abraham's bay
# City not found. Skipping...
# Processing Record 5 of Set 13 | tateyama
# Processing Record 6 of Set 13 | pangoa
# Processing Record 7 of Set 13 | rio grande
# Processing Record 8 of Set 13 | camana
# Processing Record 9 of Set 13 | turabah
# Processing Record 10 of Set 13 | lae
# Processing Record 11 of Set 13 | lerida
# Processing Record 12 of Set 13 | tanjung pandan
# Processing Record 13 of Set 13 | coos bay
# Processing Record 14 of Set 13 | acarau
# Processing Record 15 of Set 13 | naze
# Processing Record 16 of Set 13 | horodok
# Processing Record 17 of Set 13 | hohhot
# Processing Record 18 of Set 13 | suva
# Processing Record 19 of Set 13 | mbandaka
# Processing Record 20 of Set 13 | ourinhos
# Processing Record 21 of Set 13 | gamagori
# Processing Record 22 of Set 13 | kibakwe
# Processing Record 23 of Set 13 | athens
# Processing Record 24 of Set 13 | lisakovsk
# Processing Record 25 of Set 13 | pauini
# Processing Record 26 of Set 13 | alto barinas
# Processing Record 27 of Set 13 | puerto quijarro
# Processing Record 28 of Set 13 | pacific grove
# Processing Record 29 of Set 13 | lanark
# Processing Record 30 of Set 13 | luis correia
# Processing Record 31 of Set 13 | kiama
# Processing Record 32 of Set 13 | port glaud
# City not found. Skipping...
# Processing Record 33 of Set 13 | addiet canna
# Processing Record 34 of Set 13 | ketchikan
# Processing Record 35 of Set 13 | puerto ayacucho
# Processing Record 36 of Set 13 | lodwar
# Processing Record 37 of Set 13 | allapalli
# Processing Record 38 of Set 13 | gadzhiyevo
# Processing Record 39 of Set 13 | sakata
# Processing Record 40 of Set 13 | yagry
# City not found. Skipping...
# Processing Record 41 of Set 13 | yerbabuena
# Processing Record 42 of Set 13 | kidal
# Processing Record 43 of Set 13 | sanming
# Processing Record 44 of Set 13 | brookings
# Processing Record 45 of Set 13 | hasaki
# Processing Record 46 of Set 13 | kuhsan
# Processing Record 47 of Set 13 | nadym
# Processing Record 48 of Set 13 | guozhen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          618
# Lat           618
# Lng           618
# Max Temp      618
# Humidity      618
# Cloudiness    618
# Wind Speed    618
# Country       618
# Date          618
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            mawu  29.5923  107.3139     19.47        71          32
# 1  ribeira grande  38.5167  -28.7000     21.54        91          61
# 2       grytviken -54.2811  -36.5092      0.34        88         100
# 3    christchurch -43.5333  172.6333     18.30        40          20
# 4         poiares  40.2103   -8.2575     19.51        94         100
#
#    Wind Speed Country        Date
# 0        0.96      CN  1697418189
# 1        8.94      PT  1697418189
# 2        4.70      GS  1697418190
# 3        5.14      NZ  1697417544
# 4        1.61      PT  1697418190

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  mawu  29.5923  107.3139     19.47        71          32
# 1        ribeira grande  38.5167  -28.7000     21.54        91          61
# 2             grytviken -54.2811  -36.5092      0.34        88         100
# 3          christchurch -43.5333  172.6333     18.30        40          20
# 4               poiares  40.2103   -8.2575     19.51        94         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.96      CN  1697418189
# 1              8.94      PT  1697418189
# 2              4.70      GS  1697418190
# 3              5.14      NZ  1697417544
# 4              1.61      PT  1697418190

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolor="black")

# Incorporate the other graph properties with a dynamic unix conversion to specify the date
plt.title(f"City Max Latitude vs. Temperature ({pd.to_datetime(city_data_df['Date'][0], unit='s').strftime('%Y-%m-%d')})")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolor="black")

# Incorporate the other graph properties with a dynamic unix conversion to specify the date
plt.title(f"City Latitude vs. Humidity ({pd.to_datetime(city_data_df['Date'][0], unit='s').strftime('%Y-%m-%d')})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolor="black")

# Incorporate the other graph properties with a dynamic unix conversion to specify the date
plt.title(f"City Latitude vs. Cloudiness ({pd.to_datetime(city_data_df['Date'][0], unit='s').strftime('%Y-%m-%d')})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolor="black")

# Incorporate the other graph properties with a dynamic unix conversion to specify the date
plt.title(f"City Latitude vs. Wind Speed ({pd.to_datetime(city_data_df['Date'][0], unit='s').strftime('%Y-%m-%d')})")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  mawu  29.5923  107.3139     19.47        71          32
# 1        ribeira grande  38.5167  -28.7000     21.54        91          61
# 4               poiares  40.2103   -8.2575     19.51        94         100
# 5              thompson  55.7435  -97.8558      6.09        87          20
# 6            whitehorse  60.7161 -135.0538      9.43        68          20
#
#          Wind Speed Country        Date
# City_ID
# 0              0.96      CN  1697418189
# 1              8.94      PT  1697418189
# 4              1.61      PT  1697418190
# 5              0.00      CA  1697417774
# 6              6.71      CA  1697418191

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2                grytviken -54.2811  -36.5092      0.34        88         100
# 3             christchurch -43.5333  172.6333     18.30        40          20
# 8        port-aux-francais -49.3500   70.2167      1.59        72          99
# 10               adamstown -25.0660 -130.1015     22.15        78          77
# 13               piacabucu -10.4056  -36.4344     23.99        74           2
#
#          Wind Speed Country        Date
# City_ID
# 2              4.70      GS  1697418190
# 3              5.14      NZ  1697417544
# 8              9.92      TF  1697418192
# 10             2.19      PN  1697418192
# 13             4.58      BR  1697418194

# %%
# Define a function to create Linear Regression plots
def linear_regression(df, x_values, y_values, x_label, y_label):
    x = df[x_values]
    y = df[y_values]

    slope, intercept, rvalue, pvalue, stderr = stats.linregress(x, y)
    regress = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept, 2))

    plt.scatter(x, y)
    plt.plot(x, regress, "r-")

    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.annotate(line_eq, (min(x), max(y)-1), fontsize=15, color="red")
    print(f"The r-value is: {rvalue ** 2}")
    plt.show()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression(northern_hemi_df, "Lat", "Max Temp", "Latitude", "Max Temp")
# Out:
# The r-value is: 0.7682801376774139

# %%
# Linear regression on Southern Hemisphere
linear_regression(southern_hemi_df, "Lat", "Max Temp", "Latitude", "Max Temp")
# Out:
# The r-value is: 0.4989747112863876

# %% [markdown]
# **Discussion about the linear relationship:** These plots show that, in general, latitude has a strong correlation with the maximum temperature of the area. The northern hemisphere has a stronger correlation to a lower maximum temperature as the latitude increases. While the southern hemisphere correlation isn't as strong, the correlation still shows that as the latitude becomes more negative, the maximum temperature in the area decreases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df, "Lat", "Humidity", "Latitude", "Humidity")
# Out:
# The r-value is: 0.03306623688782358

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df, "Lat", "Humidity", "Latitude", "Humidity")
# Out:
# The r-value is: 0.024702321154541636

# %% [markdown]
# **Discussion about the linear relationship:** The results here show that latitude is a poor predictor of the humidity in either the Northern or Southern Hemisphere, with both r-values very close to 0. The intercept shows that the humidity is generally over 65% in both hemispheres, with the Southern Hemisphere having a higher humidity with an intercept at 75%

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df, "Lat", "Cloudiness", "Latitude", "Cloudiness")
# Out:
# The r-value is: 0.017754045759847854

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df, "Lat", "Cloudiness", "Latitude", "Cloudiness")
# Out:
# The r-value is: 0.00022148866143458182

# %% [markdown]
# **Discussion about the linear relationship:** The correlation between latitude and cloudiness in the area is very low in both hemispheres. In the Southern Hemisphere's case, the correlation is borderline non-existant. Additionally, the scatter plot shows a lot of the overall cloudiness in both hemispheres is an all or nothing type proposition, with the results clustering at the top and bottom of the plots, resulting in an intercept that does not hit many of the plot points.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df, "Lat", "Wind Speed", "Latitude", "Wind Speed")
# Out:
# The r-value is: 0.059388127182865735

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df, "Lat", "Wind Speed", "Latitude", "Wind Speed")
# Out:
# The r-value is: 0.10263137313383233

# %% [markdown]
# **Discussion about the linear relationship:** The correlation between latitude and wind speed is very low in both hemispheres. Both hemispheres have wide ranges to their results, but both plots have low intercepts that start between 2 and 3 m/s.
